# %% [markdown]
# # Introduction to Software Tools

# %% [markdown]
# ## Exercise 1: Whirlwind Tour of Python

# %%
# Addition 
1+1
# Out:
# 2

# %%
# Strings and printing
name = 'Jupyter'
print(name, 'has', len(name), 'letters')
# Out:
# Jupyter has 7 letters

# %%
# For loops
for i in range(5):
    print(i*i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
# If statements
for i in range(5):
    if i % 2:
        print(i, 'is even')
    else:
        print(i, 'is odd')
# Out:
# 0 is odd
# 1 is even
# 2 is odd
# 3 is even
# 4 is odd

# %%
# Lists
numbers = [1, 2, 3]
print(numbers)
# Out:
# [1, 2, 3]

# %%
# Installing packages
# !pip install numpy
# !pip install matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\emilycl\appdata\local\anaconda3\envs\starsim_training\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\emilycl\appdata\local\anaconda3\envs\starsim_training\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\emilycl\appdata\local\anaconda3\envs\starsim_training\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\emilycl\appdata\local\anaconda3\envs\starsim_training\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\emilycl\appdata\local\anaconda3\envs\starsim_training\lib\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\emilycl\appdata\local\anaconda3\envs\starsim_training\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\emilycl\appdata\local\anaconda3\envs\starsim_training\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\emilycl\appdata\local\anaconda3\envs\starsim_training\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\emilycl\appdata\local\anaconda3\envs\starsim_training\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\emilycl\appdata\local\anaconda3\envs\starsim_training\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\emilycl\appdata\local\anaconda3\envs\starsim_training\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\emilycl\appdata\local\anaconda3\envs\starsim_training\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# Imports
import pandas as pd
import pylab as pl

# %%
# Plotting
pl.plot([1, 2, 3], [20, 15, 30])

# %% [markdown]
# ## Exercise 2: Loading and Plotting Data

# %%
# Read in a csv file
data = pd.read_csv('titanic.csv')

# %%
# Plot a column of the data; here we plot the ages of the passengers aboard the Titanic
pl.hist(data.Age)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)
